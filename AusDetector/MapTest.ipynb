# %%
#Mitchell Schiworksi, Jan 2019
#Code to test plotting desired area of australia, with detector locations overlayed

import numpy as np
import bilby
import gwinc
import matplotlib.pyplot as plt
import functools
import bilby.core.result
import cartopy.crs as ccrs

latitude_limits =  [-37.0,-10.0] #min/max values of lat/long
longitude_limits = [115.0,152.0]
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
plt.xlim((112.0,154.0))
plt.ylim((-40.0,-11.0))
plt.show()
